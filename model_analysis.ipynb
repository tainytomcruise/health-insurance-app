# %%
import pandas as pd

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install seaborn matplotlib
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl.metadata (52 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./ml_env/lib/python3.11/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in ./ml_env/lib/python3.11/site-packages (from seaborn) (3.0.1)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in ./ml_env/lib/python3.11/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./ml_env/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./ml_env/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.8-cp311-cp311-macosx_11_0_arm64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp311-cp311-macosx_11_0_arm64.whl (270 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp311-cp311-macosx_10_9_universal2.whl (2.9 MB)
# Using cached kiwisolver-1.4.9-cp311-cp311-macosx_11_0_arm64.whl (65 kB)
# Using cached pillow-12.1.1-cp311-cp311-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]m6/8 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance.csv")

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1  39.0    male  23.2             91      Yes         0     No
# 1        2  24.0    male  30.1             87       No         0     No
# 2        3   NaN    male  33.3             82      Yes         0     No
# 3        4   NaN    male  33.7             80       No         0     No
# 4        5   NaN    male  34.1            100       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336  44.0  female  35.5             88      Yes         0    Yes
# 1336  1337  59.0  female  38.1            120       No         1    Yes
# 1337  1338  30.0    male  34.5             91      Yes         3    Yes
# 1338  1339  37.0    male  30.4            106       No         0    Yes
# 1339  1340  30.0  female  47.4            101       No         0    Yes
#
#          region     claim
# 0     southeast   1121.87
# 1     southeast   1131.51
# 2     southeast   1135.94
# 3     northwest   1136.40
# 4     northwest   1137.01
# ...         ...       ...
# 1335  northwest  55135.40
# 1336  northeast  58571.07
# 1337  northwest  60021.40
# 1338  southeast  62592.87
# 1339  southeast  63770.43
#
# [1340 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1340 non-null   int64
#  1   age            1335 non-null   float64
#  2   gender         1340 non-null   str
#  3   bmi            1340 non-null   float64
#  4   bloodpressure  1340 non-null   int64
#  5   diabetic       1340 non-null   str
#  6   children       1340 non-null   int64
#  7   smoker         1340 non-null   str
#  8   region         1337 non-null   str
#  9   claim          1340 non-null   float64
# dtypes: float64(3), int64(3), str(4)
# memory usage: 104.8 KB

# %%
df.shape
# Out:
# (1340, 10)

# %%
pd.set_option("display.float_format","{:.2f}".format)

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 2        3   NaN    male 33.30             82      Yes         0     No
# 3        4   NaN    male 33.70             80       No         0     No
# 4        5   NaN    male 34.10            100       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim
# 0     southeast  1121.87
# 1     southeast  1131.51
# 2     southeast  1135.94
# 3     northwest  1136.40
# 4     northwest  1137.01
# ...         ...      ...
# 1335  northwest 55135.40
# 1336  northeast 58571.07
# 1337  northwest 60021.40
# 1338  southeast 62592.87
# 1339  southeast 63770.43
#
# [1340 rows x 10 columns]

# %%
sns.set(style="whitegrid", palette="Set2", font_scale=1.1)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna()
# Out:
#          Id    age  gender    bmi  bloodpressure  diabetic  children  smoker  \
# 0     False  False   False  False          False     False     False   False
# 1     False  False   False  False          False     False     False   False
# 2     False   True   False  False          False     False     False   False
# 3     False   True   False  False          False     False     False   False
# 4     False   True   False  False          False     False     False   False
# ...     ...    ...     ...    ...            ...       ...       ...     ...
# 1335  False  False   False  False          False     False     False   False
# 1336  False  False   False  False          False     False     False   False
# 1337  False  False   False  False          False     False     False   False
# 1338  False  False   False  False          False     False     False   False
# 1339  False  False   False  False          False     False     False   False
#
#       region  claim
# 0      False  False
# 1      False  False
# 2      False  False
# 3      False  False
# 4      False  False
# ...      ...    ...
# 1335   False  False
# 1336   False  False
# 1337   False  False
# 1338   False  False
# 1339   False  False
#
# [1340 rows x 10 columns]

# %%
df.isna().sum().sum()
# Out:
# np.int64(8)

# %%
df.dropna()
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 7        8 19.00    male 41.10            100       No         0     No
# 8        9 20.00    male 43.00             86       No         0     No
# 9       10 30.00    male 53.10             97       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim
# 0     southeast  1121.87
# 1     southeast  1131.51
# 7     northwest  1146.80
# 8     northwest  1149.40
# 9     northwest  1163.46
# ...         ...      ...
# 1335  northwest 55135.40
# 1336  northeast 58571.07
# 1337  northwest 60021.40
# 1338  southeast 62592.87
# 1339  southeast 63770.43
#
# [1332 rows x 10 columns]

# %%
df.shape
# Out:
# (1340, 10)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (1332, 10)

# %%
df.describe(include="all")
# Out:
#             Id     age gender     bmi  bloodpressure diabetic  children  \
# count  1332.00 1332.00   1332 1332.00        1332.00     1332   1332.00
# unique     NaN     NaN      2     NaN            NaN        2       NaN
# top        NaN     NaN   male     NaN            NaN       No       NaN
# freq       NaN     NaN    670     NaN            NaN      695       NaN
# mean    674.47   38.09    NaN   30.66          94.19      NaN      1.10
# std     384.70   11.11    NaN    6.12          11.45      NaN      1.21
# min       1.00   18.00    NaN   16.00          80.00      NaN      0.00
# 25%     341.75   29.00    NaN   26.20          86.00      NaN      0.00
# 50%     674.50   38.00    NaN   30.35          92.00      NaN      1.00
# 75%    1007.25   47.00    NaN   34.73          99.00      NaN      2.00
# max    1340.00   60.00    NaN   53.10         140.00      NaN      5.00
#
#        smoker     region    claim
# count    1332       1332  1332.00
# unique      2          4      NaN
# top        No  southeast      NaN
# freq     1058        442      NaN
# mean      NaN        NaN 13325.25
# std       NaN        NaN 12109.62
# min       NaN        NaN  1121.87
# 25%       NaN        NaN  4760.16
# 50%       NaN        NaN  9412.97
# 75%       NaN        NaN 16781.33
# max       NaN        NaN 63770.43

# %%
df[df["gender"]=="female"]
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 24      25 50.00  female 20.80             85      Yes         0     No
# 26      27 36.00  female 26.70             97      Yes         0     No
# 28      29 58.00  female 31.10             87       No         0     No
# 29      30 35.00  female 31.40             93       No         0     No
# 33      34 52.00  female 36.90             81       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1329  1330 52.00  female 37.70            109      Yes         0    Yes
# 1330  1331 25.00  female 38.10            111       No         0    Yes
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim
# 24    southeast  1607.51
# 26    southeast  1615.77
# 28    southeast  1621.88
# 29    southeast  1622.19
# 33    southeast  1629.83
# ...         ...      ...
# 1329  southwest 48824.45
# 1330  southeast 48885.14
# 1335  northwest 55135.40
# 1336  northeast 58571.07
# 1339  southeast 63770.43
#
# [662 rows x 10 columns]

# %%
(df["gender"] == "female").sum()
# Out:
# np.int64(662)

# %%
(df["gender"] == "male").sum()
# Out:
# np.int64(670)

# %%
df.shape[0] - (df["gender"] == "female").sum()
# Out:
# np.int64(670)

# %%
numerical_cols = ["age", "bmi", "bloodpressure", "children", "claim"]

# %%
df[numerical_cols].hist(bins=20, figsize=(12,8), color="skyblue", edgecolor="black")
plt.suptitle("DIstribution of Numerical Columns", fontsize=16)
plt.show()

# %%
cat_cols = ["gender", "diabetic", "region", "smoker"]

# %%
plt.figure(figsize=(12,8))
for i, col in enumerate(cat_cols, 1):
    plt.subplot(2,2,i)
    sns.countplot(data=df, x = col)
    plt.title(f"Distribution of {col}")
    
plt.tight_layout()
plt.show()

# %%
df.groupby(["gender", "smoker"])["claim"].mean().round(2)
# Out:
# gender  smoker
# female  No        8762.30
#         Yes      30679.00
# male    No        8169.25
#         Yes      33042.01
# Name: claim, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df, x="gender", y = "claim", hue="smoker", estimator="mean", errorbar="sd")
plt.title("Average Insurance Claim by Gender and Smoking Status")
plt.show()

# %%
pivot_region_diabetic = df.groupby(["region", "diabetic"])["claim"].mean().unstack()

# %%
pivot_region_diabetic
# Out:
# diabetic        No      Yes
# region
# northeast 16966.86 16818.30
# northwest 11442.83 12224.96
# southeast 13578.72 12574.09
# southwest 13069.91 12313.74

# %%
pivot_region_diabetic.plot(kind = "bar", figsize=(12,8))
plt.title("Average Claim by Region and DIabetic Status")
plt.ylabel("Mean Claim")
plt.show()

# %%
pivot_table = pd.pivot_table(df, values="claim", index="region", columns="smoker", aggfunc="mean")
pivot_table
# Out:
# smoker          No      Yes
# region
# northeast 11666.11 29673.54
# northwest  8076.20 30192.00
# southeast  7444.14 34845.00
# southwest  8294.75 32269.06

# %%
pivot_table = pd.pivot_table(df, values="claim", index="children", columns="diabetic", aggfunc="mean")
pivot_table
# Out:
# diabetic       No      Yes
# children
# 0        12967.40 11985.29
# 1        12730.46 12732.06
# 2        15567.77 14579.36
# 3        13807.61 17091.26
# 4        14106.63 13573.35
# 5         8519.04  9205.59

# %%
numerical_cols
# Out:
# ['age', 'bmi', 'bloodpressure', 'children', 'claim']

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(data=df, x="age", y="claim", hue="smoker", style="gender", alpha=0.7)
plt.title("Claim vs age by smoker and Gender")
# Out:
# Text(0.5, 1.0, 'Claim vs age by smoker and Gender')

# %%
sns.histplot(df["claim"], bins=20)
# Out:
# <Axes: xlabel='claim', ylabel='Count'>

# %%
sns.countplot(x=df["gender"])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.regplot(data=df, x="bmi", y="claim", scatter_kws={"alpha":0.6})
plt.title("Relationship Between BMI and Claim Amount")
plt.show()

# %%
sns.boxplot(data=df, x = "children", y="claim")
plt.title("Claim Distribution by number of Children")
plt.show()

# %%
df["age_group"] = pd.cut(
    df["age"],
    bins=[0, 18, 30, 45, 60, 100],
    labels=["less than 18", "18-30", "31-45", "45-60", "more than 60"] )
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 7        8 19.00    male 41.10            100       No         0     No
# 8        9 20.00    male 43.00             86       No         0     No
# 9       10 30.00    male 53.10             97       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim age_group
# 0     southeast  1121.87     31-45
# 1     southeast  1131.51     18-30
# 7     northwest  1146.80     18-30
# 8     northwest  1149.40     18-30
# 9     northwest  1163.46     18-30
# ...         ...      ...       ...
# 1335  northwest 55135.40     31-45
# 1336  northeast 58571.07     45-60
# 1337  northwest 60021.40     18-30
# 1338  southeast 62592.87     31-45
# 1339  southeast 63770.43     18-30
#
# [1332 rows x 11 columns]

# %%
df["age_group"].value_counts()
# Out:
# age_group
# 31-45           553
# 45-60           383
# 18-30           380
# less than 18     16
# more than 60      0
# Name: count, dtype: int64

# %%
sns.barplot(data=df, x="age_group", y = "claim", estimator="mean", errorbar="sd")
plt.title("Average Claim by Age Group")
plt.show()

# %%
df["bmi_category"] = pd.cut(df["bmi"], bins=[0, 18.5, 24.9, 29.9, 100], labels=["Underweight", "Normal", "Overweight", "Obese"])

# %%
df["bmi_category"].value_counts()
# Out:
# bmi_category
# Obese          702
# Overweight     387
# Normal         222
# Underweight     21
# Name: count, dtype: int64

# %%
sns.boxplot(data=df, x="bmi_category", y="claim", hue="smoker")
plt.title("Claim Distribution by BMI Category &Smoking Status")
plt.show()

# %%
region_stats= df.groupby("region").agg(
    smoker_rate = ("smoker", lambda x: (x=="Yes").mean()*100),
    mean_claim = ("claim", "mean")
).reset_index()

# %%
region_stats
# Out:
#       region  smoker_rate  mean_claim
# 0  northeast        29.00    16889.04
# 1  northwest        16.81    11794.22
# 2  southeast        20.59    13085.50
# 3  southwest        18.47    12723.13

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))
sns.barplot(data=region_stats, x = "region", y = "smoker_rate", ax=ax1, alpha=0.6)
ax2 = ax1.twinx()
sns.lineplot(data=region_stats, x="region", y="mean_claim", ax=ax2, color="red", marker="o")
ax1.set_ylabel("Smaoker Rate (%)")
ax2.setlabel("Average CLaim($)")
plt.title("Smaoker Rate and Average CLaim by Region")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 6
#       4 sns.lineplot(data=region_stats, x="region", y="mean_claim", ax=ax2, color="red", marker="o")
#       5 ax1.set_ylabel("Smaoker Rate (%)")
# ----> 6 ax2.setlabel("Average CLaim($)")
#       7 plt.title("Smaoker Rate and Average CLaim by Region")
#       8 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'setlabel'

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import joblib

# %%
df
# Out:
#         Id   age  gender   bmi  bloodpressure diabetic  children smoker  \
# 0        1 39.00    male 23.20             91      Yes         0     No
# 1        2 24.00    male 30.10             87       No         0     No
# 7        8 19.00    male 41.10            100       No         0     No
# 8        9 20.00    male 43.00             86       No         0     No
# 9       10 30.00    male 53.10             97       No         0     No
# ...    ...   ...     ...   ...            ...      ...       ...    ...
# 1335  1336 44.00  female 35.50             88      Yes         0    Yes
# 1336  1337 59.00  female 38.10            120       No         1    Yes
# 1337  1338 30.00    male 34.50             91      Yes         3    Yes
# 1338  1339 37.00    male 30.40            106       No         0    Yes
# 1339  1340 30.00  female 47.40            101       No         0    Yes
#
#          region    claim age_group bmi_category
# 0     southeast  1121.87     31-45       Normal
# 1     southeast  1131.51     18-30        Obese
# 7     northwest  1146.80     18-30        Obese
# 8     northwest  1149.40     18-30        Obese
# 9     northwest  1163.46     18-30        Obese
# ...         ...      ...       ...          ...
# 1335  northwest 55135.40     31-45        Obese
# 1336  northeast 58571.07     45-60        Obese
# 1337  northwest 60021.40     18-30        Obese
# 1338  southeast 62592.87     31-45        Obese
# 1339  southeast 63770.43     18-30        Obese
#
# [1332 rows x 12 columns]

# %%
X = df[["age", "gender", "bmi", "bloodpressure", "diabetic", "children", "smoker"]].copy()
y = df["claim"]

# %%
cat_cols = ["gender", "diabetic", "smoker"]
label_encoders={}

# %%
for col in cat_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le
    
    joblib.dump(le, f"label_encoder_{col}.pkl")

# %%
X
# Out:
#        age  gender   bmi  bloodpressure  diabetic  children  smoker
# 0    39.00       1 23.20             91         1         0       0
# 1    24.00       1 30.10             87         0         0       0
# 7    19.00       1 41.10            100         0         0       0
# 8    20.00       1 43.00             86         0         0       0
# 9    30.00       1 53.10             97         0         0       0
# ...    ...     ...   ...            ...       ...       ...     ...
# 1335 44.00       0 35.50             88         1         0       1
# 1336 59.00       0 38.10            120         0         1       1
# 1337 30.00       1 34.50             91         1         3       1
# 1338 37.00       1 30.40            106         0         0       1
# 1339 30.00       0 47.40            101         0         0       1
#
# [1332 rows x 7 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
num_cols=["age","bmi", "bloodpressure", "children"]
scaler = StandardScaler()

# %%
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_test[num_cols] = scaler.transform(X_test[num_cols])

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
print(X_train.shape, y_train.shape)
# Out:
# (1065, 7) (1065,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (267, 7) (267,)

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from xgboost import XGBRegressor

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in ./ml_env/lib/python3.11/site-packages (1.7.6)
# Requirement already satisfied: numpy in ./ml_env/lib/python3.11/site-packages (from xgboost) (2.4.2)
# Requirement already satisfied: scipy in ./ml_env/lib/python3.11/site-packages (from xgboost) (1.17.1)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import platform
platform.architecture()
# Out:
# ('64bit', '')

# %%
import platform
platform.machine()
# Out:
# 'arm64'

# %%
brew install python
# Out:
#   Cell In[136], line 1
#     brew install python
#          ^
# SyntaxError: invalid syntax

# %%
platform.machine()
# Out:
# 'arm64'

# %%
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 from xgboost import XGBRegressor
#
# File ~/Library/Python/3.9/lib/python/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective, dask
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)
#      15     build_info,
#      16 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/Library/Python/3.9/lib/python/site-packages/xgboost/core.py:269
#     265     return lib
#     268 # load the XGBoost library globally
# --> 269 _LIB = _load_lib()
#     272 def _check_call(ret: int) -> None:
#     273     """Check the return value of C API call
#     274
#     275     This function will raise exception when error occurs.
#    (...)
#     281         return value from API calls
#     282     """
#
# File ~/Library/Python/3.9/lib/python/site-packages/xgboost/core.py:222, in _load_lib()
#     220     if not lib_success:
#     221         libname = os.path.basename(lib_paths[0])
# --> 222         raise XGBoostError(
#     223             f"""
#     224 XGBoost Library ({libname}) could not be loaded.
#     225 Likely causes:
#     226   * OpenMP runtime is not installed
#     227     - vcomp140.dll or libgomp-1.dll for Windows
#     228     - libomp.dylib for Mac OSX
#     229     - libgomp.so for Linux and other UNIX-like OSes
#     230     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     231
#     232   * You are running 32-bit Python on a 64-bit OS
#     233
#     234 Error message(s): {os_error_list}
#     235 """
#     236         )
#     237     _register_log_callback(lib)
#     239     def parse(ver: str) -> Tuple[int, int, int]:
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ["dlopen(/Users/tainytomcruise/Library/Python/3.9/lib/python/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib\n  Referenced from: <89AD948E-E564-3266-867D-7AF89D6488F0> /Users/tainytomcruise/Library/Python/3.9/lib/python/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file)"]

# %%
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from xgboost import XGBRegressor
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/__init__.py:6
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
# ----> 6 from . import tracker  # noqa
#       7 from . import collective
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)     15     build_info,
#      16 )
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/tracker.py:9
#       6 from enum import IntEnum, unique
#       7 from typing import Dict, Optional, Union
# ----> 9 from .core import _LIB, _check_call, _deprecate_positional_args, make_jcargs
#      12 def get_family(addr: str) -> int:
#      13     """Get network family from address."""
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/core.py:309
#     305     return lib
#     308 # load the XGBoost library globally
# --> 309 _LIB = _load_lib()
#     312 def _check_call(ret: int) -> None:
#     313     """Check the return value of C API call
#     314
#     315     This function will raise exception when error occurs.
#    (...)    321         return value from API calls
#     322     """
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/core.py:273, in _load_lib()
#     271     if not lib_success:
#     272         libname = os.path.basename(lib_paths[0])
# --> 273         raise XGBoostError(f"""
#     274 XGBoost Library ({libname}) could not be loaded.
#     275 Likely causes:
#     276   * OpenMP runtime is not installed
#     277     - vcomp140.dll or libgomp-1.dll for Windows
#     278     - libomp.dylib for Mac OSX
#     279     - libgomp.so for Linux and other UNIX-like OSes
#     280     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#     281
#     282   * You are running 32-bit Python on a 64-bit OS
#     283
#     284 Error message(s): {os_error_list}
#     285 """)
#     286     _register_log_callback(lib)
#     288     libver = _lib_version(lib)
#
# XGBoostError:
# XGBoost Library (libxgboost.dylib) could not be loaded.
# Likely causes:
#   * OpenMP runtime is not installed
#     - vcomp140.dll or libgomp-1.dll for Windows
#     - libomp.dylib for Mac OSX
#     - libgomp.so for Linux and other UNIX-like OSes
#     Mac OSX users: Run `brew install libomp` to install OpenMP runtime.
#
#   * You are running 32-bit Python on a 64-bit OS
#
# Error message(s): ["dlopen(/Users/tainytomcruise/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.dylib, 0x0006): Library not loaded: @rpath/libomp.dylib\n  Referenced from: <1A0D8152-BF46-3BE0-B651-EE965C187777> /Users/tainytomcruise/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/lib/libxgboost.dylib\n  Reason: tried: '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/opt/libomp/lib/libomp.dylib' (no such file), '/opt/homebrew/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libomp.dylib' (no such file)"]

# %%
Y

# %%
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from xgboost import XGBRegressor
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/__init__.py:7
#       1 """XGBoost: eXtreme Gradient Boosting library.
#       2
#       3 Contributors: https://github.com/dmlc/xgboost/blob/master/CONTRIBUTORS.md
#       4 """
#       6 from . import tracker  # noqa
# ----> 7 from . import collective, dask, rabit
#       8 from .core import (
#       9     Booster,
#      10     DataIter,
#    (...)     15     build_info,
#      16 )
#      17 from .tracker import RabitTracker  # noqa
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/collective.py:12
#       9 import numpy as np
#      11 from ._typing import _T
# ---> 12 from .core import _LIB, _check_call, c_str, py_str, from_pystr_to_cstr
#      14 LOGGER = logging.getLogger("[xgboost.collective]")
#      17 def init(**args: Any) -> None:
#
# File ~/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/core.py:52
#      32 import scipy.sparse
#      34 from ._typing import (
#      35     _T,
#      36     ArrayLike,
#    (...)     50     c_bst_ulong,
#      51 )
# ---> 52 from .compat import PANDAS_INSTALLED, DataFrame, py_str
#      53 from .libpath import find_lib_path
#      56 class XGBoostError(ValueError):
#
# ImportError: cannot import name 'PANDAS_INSTALLED' from 'xgboost.compat' (/Users/tainytomcruise/Projects/data science/InsuranceData-main/ml_env/lib/python3.11/site-packages/xgboost/compat.py)

# %%
from xgboost import XGBRegressor

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    return{"R2": r2, "MAE": mae, "RMSE": rmse}

# %%
results={}

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
results["Linear Regression"] = evaluate_model(lr, X_train, X_test, y_train, y_test)
print("Linear Regression model trained!!")
# Out:
# Linear Regression model trained!!

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler

# %%
best_poly_model = None
best_poly_score = -np.inf
for degree in [2,3]:
    poly = PolynomialFeatures(degree=degree)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    
    poly_lr = LinearRegression()
    poly_lr.fit(X_train_poly, y_train)
    score = poly_lr.score(X_test_poly, y_test)
    
    if score>best_poly_score:
        best_poly_score = score
        best_poly_model = (degree, poly, poly_lr)
degree, poly, poly_lr = best_poly_model
results[f"Polynomial Regression (deg = {degree})"] = evaluate_model(poly_lr, poly.fit_transform(X_train), poly.transform(X_test), y_train, y_test)

print("Polynomial Regreesion model are trained!!!")

rf = RandomForestRegressor()
rf_params = {
    "n_estimators": [100, 200],
    "max_depth":[None, 10, 20],
    "min_samples_split" :[2,5],
    "min_samples_leaf": [1,2]
}

rf_grid = GridSearchCV(rf, rf_params, cv = 3, scoring = "r2", n_jobs = -1, verbose = 0)
rf_grid.fit(X_train, y_train)
best_rf = rf_grid.best_estimator_

results["Random Forest"] = evaluate_model(best_rf, X_train, X_test, y_train, y_test)

print("Random Forest training is completed, best parameter ", rf_grid.best_params_)

svr = SVR()
svr_params = {
    "kernel" : ["rbf", "poly", "linear"],
    "C" : [1, 10, 50],
    "epsilon" : [0.1, 0.2, 0,5],
    "degree" : [2,3]
}
    
svr_grid = GridSearchCV(svr, svr_params, cv=3, scoring = "r2", n_jobs = -1, verbose=0)
svr_grid.fit(X_train, y_train)

best_svr = svr_grid.best_estimator_

results["SVR"] = evaluate_model(best_svr, X_train, X_test, y_train, y_test)

print("SVR trainig is completed!!, best parameters:", svr_grid.best_params_)

xgb = XGBRegressor(objective="reg:squarederror")

xgb_params = {
    "n_estimators":[100, 200],
    "max_depth":[3,5,7],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.8, 1.0]
}

xgb_grid = GridSearchCV(xgb, xgb_params, cv =3, scoring="r2", n_jobs = -1, verbose=0)
xgb_grid.fit(X_train, y_train)
best_xgb = xgb_grid.best_estimator_

results["XGBoost"] = evaluate_model(best_xgb, X_train, X_test, y_train, y_test)

print("XGBoost training is completed, best parameters: ", xgb_grid.best_params_)
# Out:
# Polynomial Regreesion model are trained!!!
# Random Forest training is completed, best parameter  {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# SVR trainig is completed!!, best parameters: {'C': 50, 'degree': 2, 'epsilon': 0, 'kernel': 'linear'}
# XGBoost training is completed, best parameters:  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.8}

# %%
results
# Out:
# {'Linear Regression': {'R2': 0.7379047926715778,
#   'MAE': 4766.965673537603,
#   'RMSE': np.float64(6228.289600258577)},
#  'Polynomial Regression (deg = 2)': {'R2': 0.8132850387731432,
#   'MAE': 4025.7322861440957,
#   'RMSE': np.float64(5256.889129731341)},
#  'Random Forest': {'R2': 0.8325002957208991,
#   'MAE': 3764.0846679603483,
#   'RMSE': np.float64(4979.047627265208)},
#  'SVR': {'R2': 0.5269212196005019,
#   'MAE': 5621.258829608753,
#   'RMSE': np.float64(8367.697901633635)},
#  'XGBoost': {'R2': 0.8486698381616943,
#   'MAE': 3597.8493651977997,
#   'RMSE': np.float64(4732.624051467267)}}

# %%
results_df = pd.DataFrame(results).T.sort_values(by="R2", ascending=False)

# %%
results_df
# Out:
#                                   R2     MAE    RMSE
# XGBoost                         0.85 3597.85 4732.62
# Random Forest                   0.83 3764.08 4979.05
# Polynomial Regression (deg = 2) 0.81 4025.73 5256.89
# Linear Regression               0.74 4766.97 6228.29
# SVR                             0.53 5621.26 8367.70

# %%
best_rf
# Out:
# RandomForestRegressor(max_depth=10, min_samples_leaf=2, min_samples_split=5)

# %%
models = {
    "Linea Regression" : lr,
    "Polynomial Regression" : poly_lr, 
     "Random Forest" : best_rf,
     "SVR" : best_svr,
     "XGBoost" : best_xgb
}

# %%
best_r2 = results_df["R2"].max()

# %%
best_r2
# Out:
# np.float64(0.8486698381616943)

# %%
top_model = results_df[results_df["R2"] == best_r2]

# %%
top_model
# Out:
#           R2     MAE    RMSE
# XGBoost 0.85 3597.85 4732.62

# %%
best_model = models[top_model.index[0]]

# %%
best_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
joblib.dump(best_model, "best_model.pkl")
print(f"Best model selected: {top_model.index[0]}")
# Out:
# Best model selected: XGBoost
